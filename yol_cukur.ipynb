# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="7rVVO91C1xm0t3qc520o")
project = rf.workspace("deneme-dpca7").project("pothole-vhmow-e0akt")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\User\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\User\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\User\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\User\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\User\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\User\anaconda3\Lib\site-packages)
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to pothole-1 in yolov8:: 100%|██████████| 7818/7818 [00:07<00:00, 1104.14it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# ...

# %%
# Train the model
results = model.train(data='/content/pothole-1/data.yaml', epochs=50, imgsz=640)
# Out:
# Ultralytics 8.3.205 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !pip install ultralytics
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\User\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\User\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\User\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\User\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\User\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\User\anaconda3\Lib\site-packages)

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv8n model
model = YOLO('yolov8n.pt')

# %%
results = model.train(data='C:/Users/User/Desktop/yol_cukur/pothole-1/data.yaml', epochs=50, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.205 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.204  Python-3.13.0 torch-2.8.0+cpu CPU (AMD Ryzen 7 4800H with Radeon Graphics)
# ...

# %%
# Perform inference on a test image
# Replace 'test.jpeg' with the actual path to your test image
results = model('yol_test.jpeg')

# Display the results using matplotlib
import matplotlib.pyplot as plt
import cv2

# Get the image with detections
img_with_detections = results[0].plot()

# Convert the image from BGR to RGB (matplotlib expects RGB)
img_with_detections_rgb = cv2.cvtColor(img_with_detections, cv2.COLOR_BGR2RGB)

# Display the image
plt.figure(figsize=(10, 10))
plt.imshow(img_with_detections_rgb)
plt.axis('off') # Hide axes
plt.show()
# Out:
# image 1/1 c:\Users\User\Desktop\yol_cukur\yol_test.jpeg: 608x640 (no detections), 76.4ms
# Speed: 4.2ms preprocess, 76.4ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 640)

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# Load the saved model
loaded_model = YOLO('runs/detect/train6/weights/best.pt')

# Perform inference on test2.jpeg
results = loaded_model('test2.jpeg')

# Display the results using matplotlib
img_with_detections = results[0].plot()

# Convert the image from BGR to RGB (matplotlib expects RGB)
img_with_detections_rgb = cv2.cvtColor(img_with_detections, cv2.COLOR_BGR2RGB)

# Display the image
plt.figure(figsize=(10, 10))
plt.imshow(img_with_detections_rgb)
plt.axis('off') # Hide axes
plt.show()
# Out:
# image 1/1 /content/test2.jpeg: 352x640 1 pothole, 41.7ms
# Speed: 1.4ms preprocess, 41.7ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)

# %%
# List the contents of the runs directory to find the trained model file
# !ls -R /content/runs/detect/train6/weights/
# Out:
# /content/runs/detect/train6/weights/:
# best.pt  last.pt

# %%
# Save the trained model
model.save('yol_best')

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Doğru model yolunu belirt
best_model_path = "C:/Users/User/Desktop/yol_cukur/yol_best.pt"

# Modeli yükle
model = YOLO(best_model_path)

# Test görseli
test_image_path = "yol_test.jpeg"

# Modeli test görseline uygula
results = model.predict(source=test_image_path)

# Tespitleri görselleştir
img_with_detections = results[0].plot()

# Görseli kaydet
cv2.imwrite("test_result.jpg", img_with_detections)

# Görseli matplotlib ile göster
img_with_detections_rgb = cv2.cvtColor(img_with_detections, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(img_with_detections_rgb)
plt.axis('off')
plt.show()
# Out:
# image 1/1 c:\Users\User\Desktop\yol_cukur\yol_test.jpeg: 608x640 8 potholes, 185.3ms
# Speed: 12.9ms preprocess, 185.3ms inference, 20.7ms postprocess per image at shape (1, 3, 608, 640)

# %%
from ultralytics import YOLO

model = YOLO("yol_best.pt")
print(model)
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
# ...

# %%
# Eğer Jupyter Notebook kullanıyorsan:
# !pip install --upgrade onnx onnxruntime onnx-simplifier
# Out:
# ...
#      ---------------------------------------- 0.0/21.0 MB ? eta -:--:--
#      - -------------------------------------- 0.8/21.0 MB 5.6 MB/s eta 0:00:04
#      -- ------------------------------------- 1.6/21.0 MB 8.3 MB/s eta 0:00:03
#      -------- ------------------------------- 4.7/21.0 MB 8.9 MB/s eta 0:00:02
#      ------------- -------------------------- 7.1/21.0 MB 9.7 MB/s eta 0:00:02
#      ----------------- ---------------------- 9.2/21.0 MB 9.7 MB/s eta 0:00:02
#      --------------------- ------------------ 11.3/21.0 MB 9.8 MB/s eta 0:00:01
#      ------------------------- -------------- 13.4/21.0 MB 9.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 15.2/21.0 MB 9.8 MB/s eta 0:00:01
#      -------------------------------- ------- 17.3/21.0 MB 9.7 MB/s eta 0:00:01
#      ------------------------------------ --- 19.4/21.0 MB 9.8 MB/s eta 0:00:01
#      ---------------------------------------- 21.0/21.0 MB 9.7 MB/s  0:00:02
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python313\python.exe

# %%
from ultralytics import YOLO

# Eğitilmiş modelini yükle
model = YOLO("yol_best.pt")

# ONNX'e dönüştür
model.export(format="onnx")
# Out:
# Ultralytics 8.3.204  Python-3.13.0 torch-2.8.0+cpu CPU (AMD Ryzen 7 4800H with Radeon Graphics)
# PyTorch: starting from 'yol_best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.9 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim>=0.1.67', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#
# requirements: AutoUpdate success  3.2s
# WARNING requirements: Restart runtime or rerun command for updates to take effect
#
# ERROR ONNX: export failure 3.2s: No module named 'onnx'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 7
#       4 model = YOLO("yol_best.pt")
#       6 # ONNX'e dönüştür
# ----> 7 model.export(format="onnx")
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\model.py:736, in Model.export(self, **kwargs)
#     728 custom = {
# ...
